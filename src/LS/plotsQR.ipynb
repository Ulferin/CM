# %%
import sys
# Insert base project path here, like:
sys.path.append("../../")


import random

import numpy as np
import matplotlib.pyplot as plt

from src.utils import *
from src.LS.utils import *

random.seed(42) # Needed for reproducibility

# %% [markdown]
# # Scaling test

# %%
starting_m = 1000
last_m = 10000
n = 100
step = 1000
repeat = 5
time_qr_np, time_qr_a3, time_ls_np, time_ls_a3 = scaling(starting_m, last_m, n, step, repeat)
# Out:
# n=100, m=10000, t=5
# m        QR A3      delta      QR np      delta      LS A3      delta      LS np      delta
# ----------------------------------------------------------------------------------------------------
# 1000   || 162.6644 | 162.6644 |   8.7032 |   8.7032 |  93.1740 |  93.1740 |   8.1184 |   8.1184
# 2000   || 228.9294 |  66.2650 |  11.4904 |   2.7872 | 219.2556 | 126.0816 |  10.9846 |   2.8662
# 3000   || 326.7174 |  97.7880 |  23.4880 |  11.9976 | 230.4226 |  11.1670 |  15.2824 |   4.2978
# 4000   || 390.0560 |  63.3386 |  23.6082 |   0.1202 | 269.5034 |  39.0808 |  18.4978 |   3.2154
# 5000   || 437.5216 |  47.4656 |  34.7826 |  11.1744 | 331.0196 |  61.5162 |  26.9728 |   8.4750
# 6000   || 546.8860 | 109.3644 |  32.0216 |  -2.7610 | 365.9824 |  34.9628 |  27.4636 |   0.4908
# 7000   || 564.2178 |  17.3318 |  37.9700 |   5.9484 | 378.3622 |  12.3798 |  21.9750 |  -5.4886
# 8000   || 596.1676 |  31.9498 |  43.6962 |   5.7262 | 426.2990 |  47.9368 |  26.7042 |   4.7292
# 9000   || 655.1402 |  58.9726 |  52.8598 |   9.1636 | 475.6340 |  49.3350 |  32.9856 |   6.2814
# 10000  || 804.0100 | 148.8698 |  59.7836 |   6.9238 | 552.7448 |  77.1108 |  44.2854 |  11.2998
#
# m        residual A3              residual np              reconstruct a3           reconstruct np
# ----------------------------------------------------------------------------------------------------
# 1000   ||     0.9450936008544792 |     0.9450936008544792 |  7.765677475686324e-16 |  6.020268069683599e-16
# 2000   ||     0.9705916896760737 |     0.9705916896760737 |  7.962723370017502e-16 |  5.979895709066948e-16
# 3000   ||      0.983586486629073 |      0.983586486629073 |  7.766924304121975e-16 |  5.616747003183664e-16
# 4000   ||     0.9872499738329159 |     0.9872499738329159 |  9.434257842812603e-16 |  5.508089574666162e-16
# 5000   ||     0.9927821974100874 |     0.9927821974100872 |  9.532561458214798e-16 |  5.354848936106645e-16
# 6000   ||     0.9908237454707748 |     0.9908237454707748 |  9.268415369558396e-16 |   5.29745274314344e-16
# 7000   ||     0.9929469544235017 |     0.9929469544235017 |  8.494059341918153e-16 |  5.241177081371958e-16
# 8000   ||     0.9929790171877012 |     0.9929790171877012 | 1.1396846910227082e-15 |  5.198804064321444e-16
# 9000   ||     0.9944909280833959 |     0.9944909280833959 |    1.2446028256768e-15 |  5.164152121496968e-16
# 10000  ||     0.9956339821876395 |     0.9956339821876395 | 1.1629675456397205e-15 |  5.150006032895131e-16
#
# Solved (m x n): (1000,100) in 93.174 msec, w/ np in 8.1184 msec - Reverting and reconstruction: 162.6644 msec, w/ np took: 8.703199999999999 msec
# res error: 0.9450936008544792 - np_res error: 0.9450936008544792
# QR error: 7.765677475686324e-16 - QR error w/ np: 6.020268069683599e-16
#
# Solved (m x n): (2000,100) in 219.25560000000002 msec, w/ np in 10.984599999999999 msec - Reverting and reconstruction: 228.9294 msec, w/ np took: 11.4904 msec
# res error: 0.9705916896760737 - np_res error: 0.9705916896760737
# QR error: 7.962723370017502e-16 - QR error w/ np: 5.979895709066948e-16
#
# Solved (m x n): (3000,100) in 230.42260000000002 msec, w/ np in 15.2824 msec - Reverting and reconstruction: 326.7174 msec, w/ np took: 23.488000000000003 msec
# res error: 0.983586486629073 - np_res error: 0.983586486629073
# QR error: 7.766924304121975e-16 - QR error w/ np: 5.616747003183664e-16
#
# Solved (m x n): (4000,100) in 269.5034 msec, w/ np in 18.4978 msec - Reverting and reconstruction: 390.056 msec, w/ np took: 23.6082 msec
# res error: 0.9872499738329159 - np_res error: 0.9872499738329159
# QR error: 9.434257842812603e-16 - QR error w/ np: 5.508089574666162e-16
#
# Solved (m x n): (5000,100) in 331.0196 msec, w/ np in 26.9728 msec - Reverting and reconstruction: 437.52160000000003 msec, w/ np took: 34.7826 msec
# res error: 0.9927821974100874 - np_res error: 0.9927821974100872
# QR error: 9.532561458214798e-16 - QR error w/ np: 5.354848936106645e-16
#
# Solved (m x n): (6000,100) in 365.9824 msec, w/ np in 27.463600000000003 msec - Reverting and reconstruction: 546.8860000000001 msec, w/ np took: 32.0216 msec
# res error: 0.9908237454707748 - np_res error: 0.9908237454707748
# QR error: 9.268415369558396e-16 - QR error w/ np: 5.29745274314344e-16
#
# Solved (m x n): (7000,100) in 378.36220000000003 msec, w/ np in 21.975 msec - Reverting and reconstruction: 564.2178 msec, w/ np took: 37.97 msec
# res error: 0.9929469544235017 - np_res error: 0.9929469544235017
# QR error: 8.494059341918153e-16 - QR error w/ np: 5.241177081371958e-16
#
# Solved (m x n): (8000,100) in 426.299 msec, w/ np in 26.704199999999997 msec - Reverting and reconstruction: 596.1676 msec, w/ np took: 43.6962 msec
# res error: 0.9929790171877012 - np_res error: 0.9929790171877012
# QR error: 1.1396846910227082e-15 - QR error w/ np: 5.198804064321444e-16
#
# Solved (m x n): (9000,100) in 475.634 msec, w/ np in 32.9856 msec - Reverting and reconstruction: 655.1402 msec, w/ np took: 52.85979999999999 msec
# res error: 0.9944909280833959 - np_res error: 0.9944909280833959
# QR error: 1.2446028256768e-15 - QR error w/ np: 5.164152121496968e-16
#
# Solved (m x n): (10000,100) in 552.7448 msec, w/ np in 44.285399999999996 msec - Reverting and reconstruction: 804.01 msec, w/ np took: 59.7836 msec
# res error: 0.9956339821876395 - np_res error: 0.9956339821876395
# QR error: 1.1629675456397205e-15 - QR error w/ np: 5.150006032895131e-16

# %%
plot_stats(time_qr_np, time_qr_a3, time_ls_np, time_ls_a3, range(starting_m, last_m + step, step), n, save=False)

# %%
starting_m = 10000
last_m = 50000
n = 100
step = 10000
repeat = 5
time_qr_np, time_qr_a3, time_ls_np, time_ls_a3 = scaling(starting_m, last_m, n, step, repeat)
# Out:
# n=100, m=50000, t=5
# m        QR A3      delta      QR np      delta      LS A3      delta      LS np      delta
# ----------------------------------------------------------------------------------------------------
# 10000  || 743.7362 | 743.7362 |  57.8872 |  57.8872 | 525.3320 | 525.3320 |  33.3906 |  33.3906
# 20000  || 2212.4386 | 1468.7024 | 339.2562 | 281.3690 | 1087.5500 | 562.2180 | 144.3172 | 110.9266
# 30000  || 2890.4488 | 678.0102 | 642.4520 | 303.1958 | 1444.8030 | 357.2530 | 319.9302 | 175.6130
# 40000  || 3804.3830 | 913.9342 | 890.9556 | 248.5036 | 2012.0098 | 567.2068 | 465.8292 | 145.8990
# 50000  || 4638.0840 | 833.7010 | 1204.9878 | 314.0322 | 2585.7010 | 573.6912 | 601.7920 | 135.9628
#
# m        residual A3              residual np              reconstruct a3           reconstruct np
# ----------------------------------------------------------------------------------------------------
# 10000  ||     0.9951607539143076 |     0.9951607539143076 | 1.1519615886435959e-15 |  5.148749103711574e-16
# 20000  ||     0.9976194538002994 |     0.9976194538002994 |  7.061770665717737e-16 |  5.031006251923555e-16
# 30000  ||     0.9986406240176382 |     0.9986406240176382 |  6.947200010843552e-16 |  4.952328875199903e-16
# 40000  ||     0.9985386559032173 |     0.9985386559032173 |  8.386411785239629e-16 |    4.9491962080702e-16
# 50000  ||     0.9988687656350002 |     0.9988687656350003 |  7.598768058449468e-16 |  4.946923821334577e-16
#
# Solved (m x n): (10000,100) in 525.332 msec, w/ np in 33.3906 msec - Reverting and reconstruction: 743.7362 msec, w/ np took: 57.88719999999999 msec
# res error: 0.9951607539143076 - np_res error: 0.9951607539143076
# QR error: 1.1519615886435959e-15 - QR error w/ np: 5.148749103711574e-16
#
# Solved (m x n): (20000,100) in 1087.55 msec, w/ np in 144.31719999999999 msec - Reverting and reconstruction: 2212.4386 msec, w/ np took: 339.2562 msec
# res error: 0.9976194538002994 - np_res error: 0.9976194538002994
# QR error: 7.061770665717737e-16 - QR error w/ np: 5.031006251923555e-16
#
# Solved (m x n): (30000,100) in 1444.8030000000003 msec, w/ np in 319.9302 msec - Reverting and reconstruction: 2890.4487999999997 msec, w/ np took: 642.452 msec
# res error: 0.9986406240176382 - np_res error: 0.9986406240176382
# QR error: 6.947200010843552e-16 - QR error w/ np: 4.952328875199903e-16
#
# Solved (m x n): (40000,100) in 2012.0097999999998 msec, w/ np in 465.8292 msec - Reverting and reconstruction: 3804.3830000000003 msec, w/ np took: 890.9556 msec
# res error: 0.9985386559032173 - np_res error: 0.9985386559032173
# QR error: 8.386411785239629e-16 - QR error w/ np: 4.9491962080702e-16
#
# Solved (m x n): (50000,100) in 2585.701 msec, w/ np in 601.792 msec - Reverting and reconstruction: 4638.084 msec, w/ np took: 1204.9878 msec
# res error: 0.9988687656350002 - np_res error: 0.9988687656350003
# QR error: 7.598768058449468e-16 - QR error w/ np: 4.946923821334577e-16

# %%
plot_stats(time_qr_np, time_qr_a3, time_ls_np, time_ls_a3, range(starting_m, last_m + step, step), n, save=False)

# %% [markdown]
# # CUP test

# %% [markdown]
# The original CUP dataset with the provided dependent variable vector b, is far from being a linear problem. This can be seen by trying to solver the original CUP problem and comparing the result obtained with a "toy" problem that is linear. So, we generate a linear dependence between the original CUP dataset and a new vector b to show this.

# %%
cup = '../../data/ML-CUP20-TR.csv'

# %%
test = 'CUP'
M, _, b, _ = load_CUP(cup, split=0)
sol = np.random.rand(10)
b_new = M@sol

res, resnp = generic_test(M, b, 'ORIGINAL CUP')
analizeCond(M, b, res, resnp)


res_new, resnp_new = generic_test(M, b_new, 'LINEAR CUP')
analizeCond(M, b_new, res_new, resnp_new, sol)
# Out:
# ---------- ORIGINAL CUP DATASET ----------
# Solved (m x n): (1524,10) in 1.599 msec, w/ np in 0.318 msec - Reverting and reconstruction: 2.118 msec, w/ np took: 1.009 msec
# res error: 0.9589384066878516 - np_res error: 0.9589384066878516
# QR error: 5.490051337365104e-16 - QR error w/ np: 2.8585698651084886e-16
# Relative error on R: 3.7193062129335555e-16
# Relative error on Q: 1.7110069742313776e-15
# Relative error on QR: 6.1419620260893005e-16
#
# Theta:             1.283235131286147
# eta:               None
# kappa:             6.503404407917797
# cos(Theta):        0.2836144075659144
# cond y w.r.t b:    3.5259139639004116
# cond y w.r.t A:    22.930444414768846
# cond x w.r.t. b:   None
# cond x w.r.t. A:   None
#
# |res - resnp|/|resnp|:  2.128400840496273e-15
#
# ---------- LINEAR CUP DATASET ----------
# Solved (m x n): (1524,10) in 1.387 msec, w/ np in 0.292 msec - Reverting and reconstruction: 2.274 msec, w/ np took: 0.356 msec
# res error: 3.771567498989354e-16 - np_res error: 5.206752580472908e-16
# QR error: 5.490051337365104e-16 - QR error w/ np: 2.8585698651084886e-16
# Relative error on R: 3.7193062129335555e-16
# Relative error on Q: 1.7110069742313776e-15
# Relative error on QR: 6.1419620260893005e-16
#
# Theta:             3.771567498989354e-16
# eta:               2.53583364684005
# kappa:             6.503404407917797
# cos(Theta):        1.0
# cond y w.r.t b:    1.0
# cond y w.r.t A:    6.503404407917797
# cond x w.r.t. b:   2.5646021441595
# cond x w.r.t. A:   6.503404407917803
#
# |x - ~x|/|x|:           5.358763011270929e-16
# |res - resnp|/|resnp|:  9.540800137274478e-16

# %% [markdown]
# # Known QR

# %% [markdown]
# This test is used to check if the provided QR implementation, both via implicit computation of the vector Q^T*b and both via explicit reconstruction of the matrix Q, are suitable methods to solve basic QR problems. We generate a matrix A with a known QR factorization and we proceed by solving the QR factorization starting from A and comparing the matrix Q1 and R1 with the correct ones. We can see that even if Q1 and R1 are poor representations of the original Q and R, we have that the reconstructed A is still a good representation of the original matrix. This is due to the backward stability of the QR factorization algorithm.

# %%
test = "Known QR"
m = 500
n = 500
M, _ = generate(m, n)
C, _ = generate(m, n)
Q, _ = np.linalg.qr(C)
R = np.triu(M)

A = (Q.T)@R
x = np.random.rand(m)
b = A@x
res, resnp = generic_test(A, b, test)

ls = LS()
R2 = ls.qr(A)
Q2 = ls.revertQ()
Q3, R3 = np.linalg.qr(A)


analizeCond(A, b, res, resnp, x)

print(f"{'|Q - Q2|/|Q|:':<18} {np.linalg.norm(Q - Q2,2) / np.linalg.norm(Q, 2)}")
print(f"{'|R - R2|/|R|:':<18}{np.linalg.norm(R - R2,2) / np.linalg.norm(R, 2)}")
print(f"{'|Q - Q3|/|Q|:':<18}{np.linalg.norm(Q - Q3,2) / np.linalg.norm(Q, 2)}")
print(f"{'|R - R3|/|R|:':<18}{np.linalg.norm(Q - R3,2) / np.linalg.norm(R, 2)}")
print(f"{'|A - Q2R2|/|A|:':<18}{np.linalg.norm(Q2@R2 - A,2) / np.linalg.norm(A, 2)}")
print(f"{'|A - Q3R3|/|A|:':<18}{np.linalg.norm(Q3@R3 - A,2) / np.linalg.norm(A, 2)}")
# Out:
# ---------- Known QR DATASET ----------
# Solved (m x n): (500,500) in 308.041 msec, w/ np in 67.83 msec - Reverting and reconstruction: 1665.6390000000001 msec, w/ np took: 36.452 msec
# res error: 0.827491325399897 - np_res error: 3.481732069224497e-15
# QR error: 1.850400722549916e-15 - QR error w/ np: 1.124767312585225e-15
# Relative error on R: 1.3384482172031849
# Relative error on Q: 2.0
# Relative error on QR: 2.0621981298988718e-15
#
# Theta:             0.9746248814657565
# eta:               1.7269302718453654
# kappa:             2.0485457002910026e+17
# cos(Theta):        0.5614785003790633
# cond y w.r.t b:    1.7810120945412578
# cond y w.r.t A:    3.648484668438766e+17
# cond x w.r.t. b:   2.1126994690642973e+17
# cond x w.r.t. A:   3.5813505262198437e+34
#
# |x - ~x|/|x|:           5166802169865.232
# |res - resnp|/|resnp|:  5062124057098.102
# |Q - Q2|/|Q|:      1.9999999999999991
# |R - R2|/|R|:     1.4642373884424074
# |Q - Q3|/|Q|:     1.9999925470946192
# |R - R3|/|R|:     1.0014427340922838
# |A - Q2R2|/|A|:   1.850400722549916e-15
# |A - Q3R3|/|A|:   1.124767312585225e-15

# %% [markdown]
# # Test Random Matrix (m >> n)

# %%
test = 'RANDOM'
m = 1500     # number of rows
n = 10      # number of cols
M, b = generate(m, n)
res, resnp = generic_test(M, b, test)

analizeCond(M, b, res, resnp)

ls = LS()
R = ls.qr(M)
Q = ls.revertQ()

sol_explicit = np.linalg.inv(R)@Q.T@b
sol_implicit = np.linalg.inv(R)@(ls.implicit_Qb(b)[:n])

print(M.shape, Q.shape, R.shape, b.shape, sol_explicit.shape, (M@sol_explicit).shape)
print(f"explicit: {np.linalg.norm(M@sol_explicit - b,2) / np.linalg.norm(b,2)}")
print(f"implicit: {np.linalg.norm(M@sol_implicit - b,2) / np.linalg.norm(b,2)}")
print(f"|Q.T@(Ax-b)|/|b|: {np.linalg.norm((Q.T).dot(M@sol_explicit) - Q.T.dot(b),2) / np.linalg.norm(b,2)}")
# Out:
# ---------- RANDOM DATASET ----------
# Solved (m x n): (1500,10) in 2.317 msec, w/ np in 0.347 msec - Reverting and reconstruction: 2.535 msec, w/ np took: 0.601 msec
# res error: 0.9948288174388222 - np_res error: 0.9948288174388222
# QR error: 6.5931796010959e-16 - QR error w/ np: 3.381181049031673e-16
# Relative error on R: 2.774498638120138e-16
# Relative error on Q: 6.571083889217518e-16
# Relative error on QR: 7.278780126894536e-16
#
# Theta:             1.4690550316175532
# eta:               None
# kappa:             1.1593243198397722
# cos(Theta):        0.10156586037283649
# cond y w.r.t b:    9.845828079722025
# cond y w.r.t A:    11.414507941783068
# cond x w.r.t. b:   None
# cond x w.r.t. A:   None
#
# |res - resnp|/|resnp|:  2.0160826735320795e-15
#
# (1500, 10) (1500, 10) (10, 10) (1500, 1) (10, 1) (1500, 1)
# explicit: 0.9948288174388222
# implicit: 0.9948288174388222
# |Q.T@(Ax-b)|/|b|: 9.522253085953562e-17
